# %%
import pandas as pd
from jupyterthemes import jtplot
jtplot.style('chesterish')

# %% [markdown]
# # 2 main Datatypes
# ## Series
# ## Dataframe

# %%
series = pd.Series(["Bentley", "RollsRoyce", "Bugatti"])

# %%
series
# Out:
# 0       Bentley
# 1    RollsRoyce
# 2       Bugatti
# dtype: object

# %%
colors = pd.Series(["Black", "White", "Red"])

# %%
colors
# Out:
# 0    Black
# 1    White
# 2      Red
# dtype: object

# %%
car_data = pd.DataFrame({"Car make": series, "Colour": colors})

# %%
car_data
# Out:
#      Car make Colour
# 0     Bentley  Black
# 1  RollsRoyce  White
# 2     Bugatti    Red

# %% [markdown]
# ## Most usually you would just import data

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # axis = 1 => Column axis = 0 => Row

# %%
car_sales.to_csv("exported_car_sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported_car_sales.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Great I could've just...

# %%
car_sales_repo = pd.read_csv("https://raw.githubusercontent.com/BennyKayer/zero-to-mastery-ml/master/data/car-sales.csv")

# %%
car_sales_repo
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %% [markdown]
# ## Describe works only on numeric columns

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Make             10 non-null object
# Colour           10 non-null object
# Odometer (KM)    10 non-null int64
# Doors            10 non-null int64
# Price            10 non-null object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([300, 150, 111205])
car_prices.mean()
# Out:
# 37218.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Price"].sum()
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# # .loc & .iloc

# %%
animals = pd.Series(["cat", "dog", "parrot", "panda", "snake"], index=[0,3,9,8,3])

# %%
animals
# Out:
# 0       cat
# 3       dog
# 9    parrot
# 8     panda
# 3     snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'parrot'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
animals
# Out:
# 0       cat
# 3       dog
# 9    parrot
# 8     panda
# 3     snake
# dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0       cat
# 3       dog
# 9    parrot
# dtype: object

# %%
car_sales.loc[3:]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# car_sales.Odometer

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] < 70000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()

# %%
# solve problems %matplotlib inline import matplotlib.pyplot

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Price = car_sales.Price.replace('\D', '', regex=True).astype(int) // 100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales.Price.hist()

# %%
car_sales.Price.plot()

# %% [markdown]
# # Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# # Both inplace and reassignment are viable options

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# # Looks like inplace is True by default now, it looks like it dropped everything from the 1st NaN

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing_dropped = car_sales_missing.dropna(inplace=False)

# %%
print(car_sales_missing)
print(car_sales_missing_dropped)
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# Column from series
seats_column = pd.Series([5,5,5,5,5])
car_sales["Sales"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales["Sales"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
# Column from list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
# Has to have ALL THE VALUES
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"] / 100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# 7         4762.206
# 8         1800.000
# ...

# %%
# Create a column from single value
car_sales["Number of wheels"] = 4

# %%
car_sales["Passed Road Safely"] = True
car_sales.fillna("Passed Road Safely", inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed Road Safely
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales.drop("Passed Road Safely", axis=1, inplace=True)

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 0  toyota  White         150043      4   4000    5.0             7.5
#
#    Total fuel used  Number of wheels
# 8         1800.000                 4
# 9         1422.000                 4
# 6         3473.048                 4
# 5         4663.011                 4
# 0        11253.225                 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             3.0
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 1   honda    Red          87899      4   5000    5.0             9.2
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 0  toyota  White         150043      4   4000    5.0             7.5
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 9  nissan  White          31600      4   9700    5.0             4.5
# 4  nissan  White         213095      4   3500    5.0             8.7
#
#    Total fuel used  Number of wheels
# 6         3473.048                 4
# 8         1800.000                 4
# 5         4663.011                 4
# 1         8086.708                 4
# ...

# %%
car_sales_shuffled.reset_index(inplace=True, drop=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 0   honda   Blue          45698      4   7500    5.0             7.6
# 1  toyota  White          60000      4   6250    5.0             3.0
# 2  toyota  Green          99213      4   4500    5.0             4.7
# 3   honda    Red          87899      4   5000    5.0             9.2
# 4     bmw  Black          11179      5  22000    5.0             9.6
# 5   honda   Blue          54738      4   7000    5.0             8.7
# 6  toyota  White         150043      4   4000    5.0             7.5
# 7  toyota   Blue          32549      3   7000    5.0             5.0
# 8  nissan  White          31600      4   9700    5.0             4.5
# 9  nissan  White         213095      4   3500    5.0             8.7
#
#    Total fuel used  Number of wheels
# 0         3473.048                 4
# 1         1800.000                 4
# 2         4663.011                 4
# 3         8086.708                 4
# ...

# %%
car_sales["Odometer (MIL)"] = car_sales["Odometer (KM)"].apply(lambda x: x // 1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Odometer (MIL)
# 0        11253.225                 4         93776.0
# 1         8086.708                 4         54936.0
# ...

# %%
car_sales.rename(columns={"Number of wheels" : "Wheels"})
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sales  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Wheels  Odometer (MIL)
# 0        11253.225       4         93776.0
# 1         8086.708       4         54936.0
# 2         1627.450       4         20343.0
# ...
